# %%
import sqlite3
import numpy as np
import pandas as pd
import folium
from folium.plugins import MarkerCluster
import matplotlib.pyplot as plt
from matplotlib.colors import TABLEAU_COLORS
import seaborn as sns

from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist
from haversine import haversine, Unit
import pulp
from geopy.distance import geodesic
import networkx as nx
from networkx.algorithms.approximation import greedy_tsp
from folium.plugins import AntPath

# %%
conn = sqlite3.connect("sales_agent_co_pilot.db")

# %%
retailers_df = pd.read_sql_query("""SELECT * FROM retailers;""", conn)
retailer_map_df = pd.read_sql_query("SELECT * FROM retailer_beat_map", conn)

# %%
# Center of Retailer Universe
map_center = [
    retailers_df["Latitude"].mean(),
    retailers_df["Longitude"].mean()
]

# %%
# Create map
m = folium.Map(location=map_center, zoom_start=12)
marker_cluster = MarkerCluster().add_to(m)

for _, row in retailers_df.iterrows():
    popup = f"{row['Name']} ({row['Channel']})"
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup,
        tooltip=row["Retailer_ID"]
    ).add_to(marker_cluster)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_66fe2a9d58a8e08bb7a5dcc0faca2d61 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_66fe2a9d58a8e08bb7a5dcc0faca2d61&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_66fe2a9d58a8e08bb7a5dcc0faca2d61 = L.map(
#                 &quot;map_66fe2a9d58a8e08bb7a5dcc0faca2d61&quot;,
#                 {
#                     center: [12.897194583333334, 77.6020644],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9226e2a1894baf6f978469e373349cb0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9226e2a1894baf6f978469e373349cb0.addTo(map_66fe2a9d58a8e08bb7a5dcc0faca2d61);
#
#
#             var marker_cluster_ec8562c3d9da875965697fabcb3c8d38 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_5e52a3828099e5a10b6a908e583696b2 = L.marker(
#                 [12.852501, 77.577503],
#                 {
# }
#             ).addTo(marker_cluster_ec8562c3d9da875965697fabcb3c8d38);
#
#
#         var popup_d75c500ce6f6e03ab04ee40d46af137c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a286d09ada7aad92c4c6a032b69fee5c = $(`&lt;div id=&quot;html_a286d09ada7aad92c4c6a032b69fee5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hansen, Nguyen and Williams (Pharmacy)&lt;/div&gt;`)[0];
#                 popup_d75c500ce6f6e03ab04ee40d46af137c.setContent(html_a286d09ada7aad92c4c6a032b69fee5c);
#
#
#
#         marker_5e52a3828099e5a10b6a908e583696b2.bindPopup(popup_d75c500ce6f6e03ab04ee40d46af137c)
#         ;
#
#
#
#
#             marker_5e52a3828099e5a10b6a908e583696b2.bindTooltip(
#                 `&lt;div&gt;
#                      R0001
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_5ce2db139e6c643666bbd0b666ba3cde = L.marker(
#                 [12.863954, 77.56025],
#                 {
# }
#             ).addTo(marker_cluster_ec8562c3d9da875965697fabcb3c8d38);
#
#
#         var popup_84662b2749e81d16c0e2557a1add4250 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a2556569dbd402d70836e1dbf0bbe0b = $(`&lt;div id=&quot;html_1a2556569dbd402d70836e1dbf0bbe0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Schmidt, Moyer and Rivas (Grocery)&lt;/div&gt;`)[0];
#                 popup_84662b2749e81d16c0e2557a1add4250.setContent(html_1a2556569dbd402d70836e1dbf0bbe0b);
#
#
#
#         marker_5ce2db139e6c643666bbd0b666ba3cde.bindPopup(popup_84662b2749e81d16c0e2557a1add4250)
#         ;
#
#
#
#
#             marker_5ce2db139e6c643666bbd0b666ba3cde.bindTooltip(
#                 `&lt;div&gt;
#                      R0002
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_e8542a1039ad0e982402634e7feaf1be = L.marker(
#                 [12.909049, 77.553178],
#                 {
# }
#             ).addTo(marker_cluster_ec8562c3d9da875965697fabcb3c8d38);
#
#
#         var popup_a4cba98893a0d687e070931f9bfddbc9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6d3bf839d0a968ab2992df718c546eb = $(`&lt;div id=&quot;html_d6d3bf839d0a968ab2992df718c546eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Moss and Sons (Pharmacy)&lt;/div&gt;`)[0];
#                 popup_a4cba98893a0d687e070931f9bfddbc9.setContent(html_d6d3bf839d0a968ab2992df718c546eb);
#
#
#
#         marker_e8542a1039ad0e982402634e7feaf1be.bindPopup(popup_a4cba98893a0d687e070931f9bfddbc9)
#         ;
#
#
#
#
#             marker_e8542a1039ad0e982402634e7feaf1be.bindTooltip(
#                 `&lt;div&gt;
#                      R0003
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_2d6057e1fdfc984ab2aed6b1aff75213 = L.marker(
#                 [12.871864, 77.600536],

# %%
# Merge to get lat/lon per beat
retailers_merged = pd.merge(retailers_df, retailer_map_df, on="Retailer_ID")

# Generate color map for beats (12 unique colors)
beat_ids = sorted(retailers_merged["Beat_ID"].unique())
#colors = list(TABLEAU_COLORS.values())
colors = sns.color_palette("hls", 12).as_hex()
beat_color_map = {beat_id: colors[i % len(colors)] for i, beat_id in enumerate(beat_ids)}

# %%
m = folium.Map(location=map_center, zoom_start=12)

# Add retailers with color by beat
for _, row in retailers_merged.iterrows():
    beat = row["Beat_ID"]
    color = beat_color_map[beat]
    popup = f"Retailer: {row['Name']}<br>Beat: {beat}"
    
    folium.CircleMarker(
        location=[row['Latitude'], row['Longitude']],
        radius=5,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.8,
        popup=popup,
        tooltip=row[['Retailer_ID','Beat_ID']]
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0132234196ed4cdfebd2d80ad163d306 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0132234196ed4cdfebd2d80ad163d306&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0132234196ed4cdfebd2d80ad163d306 = L.map(
#                 &quot;map_0132234196ed4cdfebd2d80ad163d306&quot;,
#                 {
#                     center: [12.897194583333334, 77.6020644],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3377b7861c64cd09eddbc7a5f93771af = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3377b7861c64cd09eddbc7a5f93771af.addTo(map_0132234196ed4cdfebd2d80ad163d306);
#
#
#             var circle_marker_716c41c93f732fce481eac29550c6a00 = L.circleMarker(
#                 [12.852501, 77.577503],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#91db57&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#91db57&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0132234196ed4cdfebd2d80ad163d306);
#
#
#         var popup_605adda6037ef2ea2aeedc68ea2e7ef6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d6c25bea5aa75d9fe033af091180793 = $(`&lt;div id=&quot;html_5d6c25bea5aa75d9fe033af091180793&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Retailer: Hansen, Nguyen and Williams&lt;br&gt;Beat: B004&lt;/div&gt;`)[0];
#                 popup_605adda6037ef2ea2aeedc68ea2e7ef6.setContent(html_5d6c25bea5aa75d9fe033af091180793);
#
#
#
#         circle_marker_716c41c93f732fce481eac29550c6a00.bindPopup(popup_605adda6037ef2ea2aeedc68ea2e7ef6)
#         ;
#
#
#
#
#             circle_marker_716c41c93f732fce481eac29550c6a00.bindTooltip(
#                 `&lt;div&gt;
#                      Retailer_ID    R0001
# Beat_ID         B004
# Name: 0, dtype: object
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_3ec5f3ee57a550153f58cfc67dee52ab = L.circleMarker(
#                 [12.863954, 77.56025],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#57d3db&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#57d3db&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0132234196ed4cdfebd2d80ad163d306);
#
#
#         var popup_88e17e545f8d6dc9e3ee737ab58b37e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e716696b83b061cabe90f41eb0c8cf90 = $(`&lt;div id=&quot;html_e716696b83b061cabe90f41eb0c8cf90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Retailer: Schmidt, Moyer and Rivas&lt;br&gt;Beat: B007&lt;/div&gt;`)[0];
#                 popup_88e17e545f8d6dc9e3ee737ab58b37e9.setContent(html_e716696b83b061cabe90f41eb0c8cf90);
#
#
#
#         circle_marker_3ec5f3ee57a550153f58cfc67dee52ab.bindPopup(popup_88e17e545f8d6dc9e3ee737ab58b37e9)
#         ;
#
#
#
#
#             circle_marker_3ec5f3ee57a550153f58cfc67dee52ab.bindTooltip(
#                 `&lt;div&gt;
#                      Retailer_ID    R0002
# Beat_ID         B007
# Name: 1, dtype: object
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_af9a9b1e206762cbd07cafe63885335f = L.circleMarker(
#                 [12.909049, 77.553178],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#a157db&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#a157db&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0132234196ed4cdfebd2d80ad1

# %% [markdown]
# #### beat optimization

# %%
# Parameters
NUM_BEATS = 12
MIN_BEAT_SIZE = 16
MAX_BEAT_SIZE = 24

# %%
retailer_ids = retailers_df["Retailer_ID"].tolist()
coords = retailers_df[["Latitude", "Longitude"]].to_numpy()
num_retailers = len(retailer_ids)

# %%
#Use KMeans to get initial cluster centers
kmeans = KMeans(n_clusters=NUM_BEATS, random_state=42).fit(coords)
initial_centers = kmeans.cluster_centers_

# %%
#Calculate distance matrix (Haversine in kilometers)
dist_matrix = np.zeros((num_retailers, NUM_BEATS))

for i in range(num_retailers):
    for j in range(NUM_BEATS):
        latlon_i = tuple(coords[i])  # (lat, lon)
        latlon_center = tuple(initial_centers[j]) 
        dist_matrix[i][j] = haversine(latlon_i, latlon_center, unit=Unit.KILOMETERS)

# %%
#Set up pulp optimization
model = pulp.LpProblem("ConstrainedClustering", pulp.LpMinimize)

# Binary decision variables: x[i][j] = 1 if retailer i assigned to cluster j
x = [
    [pulp.LpVariable(f"x_{i}_{j}", cat="Binary") for j in range(NUM_BEATS)]
    for i in range(num_retailers)
]

# %%
# Objective: Minimize total Haversine distance
model += pulp.lpSum(dist_matrix[i][j] * x[i][j] for i in range(num_retailers) for j in range(NUM_BEATS))

# %%
# Constraint 1: Each retailer must be assigned to exactly one beat
for i in range(num_retailers):
    model += pulp.lpSum(x[i][j] for j in range(NUM_BEATS)) == 1

# %%
# Constraint 2: Cluster sizes must be within bounds
for j in range(NUM_BEATS):
    model += pulp.lpSum(x[i][j] for i in range(num_retailers)) >= MIN_BEAT_SIZE
    model += pulp.lpSum(x[i][j] for i in range(num_retailers)) <= MAX_BEAT_SIZE

# %%
#solve the optimization problem
model.solve(pulp.PULP_CBC_CMD(msg=1))
# Out:
# 1

# %%
#Extract assignments
assignments = []
for i in range(num_retailers):
    for j in range(NUM_BEATS):
        if pulp.value(x[i][j]) == 1:
            assignments.append((retailer_ids[i], f"B{j+1:03d}"))
            break

# %%
optimized_beatmap_df = pd.DataFrame(assignments, columns=["Retailer_ID", "Beat_ID"])

# %%
optimized_beatmap_df['Retailer_ID'].nunique(),optimized_beatmap_df['Beat_ID'].nunique()
# Out:
# (240, 12)

# %%
optimized_beatmap_df.head(),retailer_map_df.head()
# Out:
# (  Retailer_ID Beat_ID
#  0       R0001    B012
#  1       R0002    B004
#  2       R0003    B008
#  3       R0004    B007
#  4       R0005    B009,
#    Retailer_ID Beat_ID
#  0       R0001    B004
#  1       R0002    B007
#  2       R0003    B010
#  3       R0004    B006
#  4       R0005    B010)

# %%
optimized_beatmap_df.to_sql("retailer_beat_map_optimized", conn, if_exists="replace", index=False)
# Out:
# 240

# %%
retailers_merged_optimized = pd.merge(retailers_df, optimized_beatmap_df, on="Retailer_ID")

# Generate color map for beats (12 unique colors)
beat_ids = sorted(retailers_merged_optimized["Beat_ID"].unique())
#colors = list(TABLEAU_COLORS.values())
colors = sns.color_palette("hls", NUM_BEATS).as_hex()
beat_color_map = {beat_id: colors[i % len(colors)] for i, beat_id in enumerate(beat_ids)}

# %%
len(colors)
# Out:
# 12

# %%
m = folium.Map(location=map_center, zoom_start=12)

# Add retailers with color by beat
for _, row in retailers_merged_optimized.iterrows():
    beat = row["Beat_ID"]
    color = beat_color_map[beat]
    popup = f"Retailer: {row['Name']}<br>Beat: {beat}"
    
    folium.CircleMarker(
        location=[row['Latitude'], row['Longitude']],
        radius=5,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.8,
        popup=popup,
        tooltip=row[['Retailer_ID','Beat_ID']]
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_13d71e27400330ec12d27f38869150e5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_13d71e27400330ec12d27f38869150e5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_13d71e27400330ec12d27f38869150e5 = L.map(
#                 &quot;map_13d71e27400330ec12d27f38869150e5&quot;,
#                 {
#                     center: [12.897194583333334, 77.6020644],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e0fbdfd29db24466a78caf623ef23d4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8e0fbdfd29db24466a78caf623ef23d4.addTo(map_13d71e27400330ec12d27f38869150e5);
#
#
#             var circle_marker_9d1eb8e6472fdf8e20379c2265e7c104 = L.circleMarker(
#                 [12.852501, 77.577503],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#db5791&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#db5791&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_13d71e27400330ec12d27f38869150e5);
#
#
#         var popup_e2fbfce9dadcb569047b7ae5eaf9afa6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aab01832885cebdd21f476eeb56b3142 = $(`&lt;div id=&quot;html_aab01832885cebdd21f476eeb56b3142&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Retailer: Hansen, Nguyen and Williams&lt;br&gt;Beat: B012&lt;/div&gt;`)[0];
#                 popup_e2fbfce9dadcb569047b7ae5eaf9afa6.setContent(html_aab01832885cebdd21f476eeb56b3142);
#
#
#
#         circle_marker_9d1eb8e6472fdf8e20379c2265e7c104.bindPopup(popup_e2fbfce9dadcb569047b7ae5eaf9afa6)
#         ;
#
#
#
#
#             circle_marker_9d1eb8e6472fdf8e20379c2265e7c104.bindTooltip(
#                 `&lt;div&gt;
#                      Retailer_ID    R0001
# Beat_ID         B012
# Name: 0, dtype: object
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_700171a639c42fcf3b859944db45ddf0 = L.circleMarker(
#                 [12.863954, 77.56025],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#91db57&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#91db57&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_13d71e27400330ec12d27f38869150e5);
#
#
#         var popup_b547f64dc0484d7762b0aff14d4cddbc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f64430416f769e9a697d7f20481f6a88 = $(`&lt;div id=&quot;html_f64430416f769e9a697d7f20481f6a88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Retailer: Schmidt, Moyer and Rivas&lt;br&gt;Beat: B004&lt;/div&gt;`)[0];
#                 popup_b547f64dc0484d7762b0aff14d4cddbc.setContent(html_f64430416f769e9a697d7f20481f6a88);
#
#
#
#         circle_marker_700171a639c42fcf3b859944db45ddf0.bindPopup(popup_b547f64dc0484d7762b0aff14d4cddbc)
#         ;
#
#
#
#
#             circle_marker_700171a639c42fcf3b859944db45ddf0.bindTooltip(
#                 `&lt;div&gt;
#                      Retailer_ID    R0002
# Beat_ID         B004
# Name: 1, dtype: object
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_71ce6b0b6639bd729b0707479fa7c705 = L.circleMarker(
#                 [12.909049, 77.553178],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#5791db&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#5791db&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_13d71e27400330ec12d27f3886

# %%
optimized_beatmap_df['Beat_ID'].value_counts()
# Out:
# Beat_ID
# B012    24
# B004    24
# B007    23
# B005    23
# B002    23
# B001    22
# B009    19
# B003    17
# B006    17
# B008    16
# B011    16
# B010    16
# Name: count, dtype: int64

# %%
def compute_tsp_route(beat_id, beat_retailers):
    coords = beat_retailers[["Latitude", "Longitude"]].to_numpy()
    retailer_ids = beat_retailers["Retailer_ID"].tolist()
    n = len(retailer_ids)

    # Build full distance matrix (in km)
    dist_matrix = np.zeros((n, n))
    for i in range(n):
        for j in range(i + 1, n):
            d = geodesic(coords[i], coords[j]).km
            dist_matrix[i][j] = dist_matrix[j][i] = d

    # Find outermost retailer (farthest from centroid)
    centroid = coords.mean(axis=0)
    dists_to_center = [geodesic(tuple(c), tuple(centroid)).km for c in coords]
    start_idx = int(np.argmax(dists_to_center))

    # Build complete graph with distance weights
    G = nx.complete_graph(n)
    for i in range(n):
        for j in range(n):
            if i != j:
                G[i][j]["weight"] = dist_matrix[i][j]

    # Approximate TSP without 'start' (avoid TypeError)
    #tsp_path = nx.approximation.traveling_salesman_problem(G, cycle=False, weight="weight", method="greedy")

    tsp_path = greedy_tsp(G, weight="weight")

    # Return final path as list of tuples
    return [(beat_id, retailer_ids[i], seq + 1) for seq, i in enumerate(tsp_path)]
    return [(beat_id, retailer_ids[i], seq + 1) for seq, i in enumerate(tsp_path)]

# %%
# Run TSP for each beat
all_routes = []
for beat_id in retailers_merged_optimized["Beat_ID"].unique():
    beat_retailers = retailers_merged_optimized[retailers_merged_optimized["Beat_ID"] == beat_id].reset_index(drop=True)
    route = compute_tsp_route(beat_id, beat_retailers)
    all_routes.extend(route)

# %%
route_df = pd.DataFrame(all_routes, columns=["Beat_ID", "Retailer_ID", "Visit_Sequence"])
route_df.head()
# Out:
#   Beat_ID Retailer_ID  Visit_Sequence
# 0    B012       R0001               1
# 1    B012       R0141               2
# 2    B012       R0053               3
# 3    B012       R0218               4
# 4    B012       R0199               5

# %%
route_df['Beat_ID'].nunique()
# Out:
# 12

# %%
route_df = pd.DataFrame(all_routes, columns=["Beat_ID", "Retailer_ID", "Visit_Sequence"])
route_df.to_sql("beat_route_plan", conn, if_exists="replace", index=False)
conn.commit()
# conn.close()

# %%
conn.close()

# %%
route_merged = pd.merge(route_df, retailers_df, on="Retailer_ID")
route_merged = route_merged.sort_values(by=["Beat_ID", "Visit_Sequence"])

# Create map centered on Bengaluru
center_lat, center_lon = retailers_df["Latitude"].mean(), retailers_df["Longitude"].mean()

# %%
beat_ids = sorted(route_merged["Beat_ID"].unique())
beat_color_map = {beat_id: colors[i % len(colors)] for i, beat_id in enumerate(beat_ids)}

# %%
print(route_merged[["Beat_ID", "Retailer_ID", "Visit_Sequence"]].sort_values(["Beat_ID", "Visit_Sequence"]).head(20))
print(route_merged["Visit_Sequence"].dtype)
# Out:
#     Beat_ID Retailer_ID  Visit_Sequence
# 128    B001       R0010               1
# 129    B001       R0171               2
# 130    B001       R0212               3
# 131    B001       R0210               4
# 132    B001       R0161               5
# 133    B001       R0043               6
# 134    B001       R0238               7
# 135    B001       R0104               8
# 136    B001       R0036               9
# 137    B001       R0069              10
# 138    B001       R0229              11
# 139    B001       R0101              12
# 140    B001       R0231              13
# 141    B001       R0139              14
# 142    B001       R0040              15
# 143    B001       R0143              16
# 144    B001       R0065              17
# 145    B001       R0046              18
# 146    B001       R0207              19
# 147    B001       R0090              20
# int64

# %%
m = folium.Map(location=map_center, zoom_start=12)

# Plot ant path for each beat
for beat_id in beat_ids:
    beat_route = route_merged[route_merged["Beat_ID"] == beat_id]
    locations = beat_route[["Latitude", "Longitude"]].values.tolist()

    AntPath(
        locations,
        color=beat_color_map[beat_id],
        weight=4,
        opacity=0.8,
        dash_array=[10, 20]
    ).add_to(m)

    
    for i, row in beat_route.iterrows():
        folium.CircleMarker(
            location=(row["Latitude"], row["Longitude"]),
            radius=3,
            fill=True,
            fill_opacity=0.9,
            popup=f"{row['Retailer_ID']} - {row['Visit_Sequence']}",
            color=beat_color_map[beat_id]
        ).add_to(m)

        folium.map.Marker(
        [row["Latitude"], row["Longitude"]],
        icon=folium.DivIcon(
            html=f"""<div style="font-size: 10pt; color: black"><b>{row['Visit_Sequence']-1}</b></div>"""
        )
        ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_333599a60f42a0e5e2faf7355dd76fad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_333599a60f42a0e5e2faf7355dd76fad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_333599a60f42a0e5e2faf7355dd76fad = L.map(
#                 &quot;map_333599a60f42a0e5e2faf7355dd76fad&quot;,
#                 {
#                     center: [12.897194583333334, 77.6020644],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5d5159ea17bddc48b77929b7bc728e3c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5d5159ea17bddc48b77929b7bc728e3c.addTo(map_333599a60f42a0e5e2faf7355dd76fad);
#
#
#             ant_path_857e73421316e80811b214a8b772902a = L.polyline.antPath(
#               [[12.934749, 77.610373], [12.933923, 77.612134], [12.937272, 77.607406], [12.947429, 77.605336], [12.948072, 77.603412], [12.947798, 77.603271], [12.949957, 77.617228], [12.947384, 77.624948], [12.947189, 77.626196], [12.942652, 77.628513], [12.942391, 77.628783], [12.939898, 77.629612], [12.940841, 77.632663], [12.939266, 77.636044], [12.94291, 77.637872], [12.945004, 77.639143], [12.9469, 77.642637], [12.946436, 77.642891], [12.948051, 77.633263], [12.938971, 77.624242], [12.935673, 77.626559], [12.934958, 77.632233], [12.934749, 77.610373]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#db5f57&quot;,
#   &quot;weight&quot;: 4,
#   &quot;opacity&quot;: 0.8,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: [
# 10,
# 20,
# ],
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: false,
#   &quot;fillColor&quot;: &quot;#db5f57&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;smoothFactor&quot;: 1.0,
#   &quot;noClip&quot;: false,
#   &quot;paused&quot;: false,
#   &quot;reverse&quot;: false,
#   &quot;hardwareAcceleration&quot;: false,
#   &quot;delay&quot;: 400,
#   &quot;pulseColor&quot;: &quot;#FFFFFF&quot;,
# }
#         ).addTo(map_333599a60f42a0e5e2faf7355dd76fad);
#
#
#             var circle_marker_6f6c8a1f3c09a30a9a7f7764a95bffba = L.circleMarker(
#                 [12.934749, 77.610373],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#db5f57&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#db5f57&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_333599a60f42a0e5e2faf7355dd76fad);
#
#
#         var popup_5f2702191d4aa11f3135ca1e777f542d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0780b7b168a7901361f67ab5b9a3b17c = $(`&lt;div id=&quot;html_0780b7b168a7901361f67ab5b9a3b17c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;R0010 - 1&lt;/div&gt;`)[0];
#                 popup_5f2702191d4aa11f3135ca1e777f542d.setContent(html_0780b7b168a7901361f67ab5b9a3b17c);
#
#
#
#         circle_marker_6f6c8a1f3c09a30a9a7f7764a95bffba.bindPopup(popup_5f2702191d4aa11f3135ca1e777f542d)
#         ;
#
#
#
#
#             var marker_6c4afd9db92089f349b95ff713446f76 = L.marker(
#                 [12.934749, 77.610373],
#                 {
# }
#             ).addTo(map_333599a60f42a0e5e2faf7355dd76fad);
#
#
#             var div_icon_6853c8d31a95973a420dbbc11b576c7d = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 10pt; color: black\&quot;\u003e\u003cb\u003e0\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_6c4afd9db92089f349b95ff713446f76.setIcon(div_icon_6853c8d31a95973a420dbbc11b576c7d);
#
#
#             var circle_marker_780ca69cbfb277497e4cd6464045eaa2 = L.circleMarker(
#                 [12.933923, 77.612134],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#db5f57&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#db5f57&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap
