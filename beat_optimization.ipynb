# %%
import sqlite3
import numpy as np
import pandas as pd
import folium
from folium.plugins import MarkerCluster
import matplotlib.pyplot as plt
from matplotlib.colors import TABLEAU_COLORS
import seaborn as sns

from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist
from haversine import haversine, Unit
import pulp
from geopy.distance import geodesic
import networkx as nx
from networkx.algorithms.approximation import greedy_tsp
from folium.plugins import AntPath

# %%
conn = sqlite3.connect("sales_agent_co_pilot.db")

# %%
retailers_df = pd.read_sql_query("""SELECT * FROM retailers;""", conn)
retailer_map_df = pd.read_sql_query("SELECT * FROM retailer_beat_map", conn)

# %%
# Center of Retailer Universe
map_center = [
    retailers_df["Latitude"].mean(),
    retailers_df["Longitude"].mean()
]

# %%
# Create map
m = folium.Map(location=map_center, zoom_start=12)
marker_cluster = MarkerCluster().add_to(m)

for _, row in retailers_df.iterrows():
    popup = f"{row['Name']} ({row['Channel']})"
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=popup,
        tooltip=row["Retailer_ID"]
    ).add_to(marker_cluster)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_10a7c4dd76129a0b0f19bf932e4b9d54 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_10a7c4dd76129a0b0f19bf932e4b9d54&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_10a7c4dd76129a0b0f19bf932e4b9d54 = L.map(
#                 &quot;map_10a7c4dd76129a0b0f19bf932e4b9d54&quot;,
#                 {
#                     center: [12.897194583333334, 77.6020644],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_50dc189ad4bfb676eb054314be7eda66 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_50dc189ad4bfb676eb054314be7eda66.addTo(map_10a7c4dd76129a0b0f19bf932e4b9d54);
#
#
#             var marker_cluster_49286c70d9faa99c710ad0faf1b76cfb = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_f8eb9509d61bd8e2724d679e1e354b63 = L.marker(
#                 [12.852501, 77.577503],
#                 {
# }
#             ).addTo(marker_cluster_49286c70d9faa99c710ad0faf1b76cfb);
#
#
#         var popup_176a13a009785b070c34e3a623dd6308 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b097b2e9a2677e7892ac0b3583260509 = $(`&lt;div id=&quot;html_b097b2e9a2677e7892ac0b3583260509&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Aguirre PLC (Pharmacy)&lt;/div&gt;`)[0];
#                 popup_176a13a009785b070c34e3a623dd6308.setContent(html_b097b2e9a2677e7892ac0b3583260509);
#
#
#
#         marker_f8eb9509d61bd8e2724d679e1e354b63.bindPopup(popup_176a13a009785b070c34e3a623dd6308)
#         ;
#
#
#
#
#             marker_f8eb9509d61bd8e2724d679e1e354b63.bindTooltip(
#                 `&lt;div&gt;
#                      R0001
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_7b1cbcde7dbc72d48ddb2fac0c0006b5 = L.marker(
#                 [12.863954, 77.56025],
#                 {
# }
#             ).addTo(marker_cluster_49286c70d9faa99c710ad0faf1b76cfb);
#
#
#         var popup_9587416eb15a44c862372677ef83a67a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8a45f964f1f9e069b013da9183730e4 = $(`&lt;div id=&quot;html_a8a45f964f1f9e069b013da9183730e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Morales, Serrano and Hamilton (Grocery)&lt;/div&gt;`)[0];
#                 popup_9587416eb15a44c862372677ef83a67a.setContent(html_a8a45f964f1f9e069b013da9183730e4);
#
#
#
#         marker_7b1cbcde7dbc72d48ddb2fac0c0006b5.bindPopup(popup_9587416eb15a44c862372677ef83a67a)
#         ;
#
#
#
#
#             marker_7b1cbcde7dbc72d48ddb2fac0c0006b5.bindTooltip(
#                 `&lt;div&gt;
#                      R0002
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_80a32321c11060ce2f2c52266fbf78cf = L.marker(
#                 [12.909049, 77.553178],
#                 {
# }
#             ).addTo(marker_cluster_49286c70d9faa99c710ad0faf1b76cfb);
#
#
#         var popup_8c9458f58c07ac8e7e306b1ee35efefd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_716cac9cc5f1e9688b0079743ed1b7d4 = $(`&lt;div id=&quot;html_716cac9cc5f1e9688b0079743ed1b7d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Riley-Patton (Pharmacy)&lt;/div&gt;`)[0];
#                 popup_8c9458f58c07ac8e7e306b1ee35efefd.setContent(html_716cac9cc5f1e9688b0079743ed1b7d4);
#
#
#
#         marker_80a32321c11060ce2f2c52266fbf78cf.bindPopup(popup_8c9458f58c07ac8e7e306b1ee35efefd)
#         ;
#
#
#
#
#             marker_80a32321c11060ce2f2c52266fbf78cf.bindTooltip(
#                 `&lt;div&gt;
#                      R0003
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_ea7f3e2ffb57c3b6a7e7affee72a9c68 = L.marker(
#                 [12.871864, 77.600536],
#                 {

# %%
# Merge to get lat/lon per beat
retailers_merged = pd.merge(retailers_df, retailer_map_df, on="Retailer_ID")

# Generate color map for beats (12 unique colors)
beat_ids = sorted(retailers_merged["Beat_ID"].unique())
#colors = list(TABLEAU_COLORS.values())
colors = sns.color_palette("hls", 12).as_hex()
beat_color_map = {beat_id: colors[i % len(colors)] for i, beat_id in enumerate(beat_ids)}

# %%
m = folium.Map(location=map_center, zoom_start=12)

# Add retailers with color by beat
for _, row in retailers_merged.iterrows():
    beat = row["Beat_ID"]
    color = beat_color_map[beat]
    popup = f"Retailer: {row['Name']}<br>Beat: {beat}"
    
    folium.CircleMarker(
        location=[row['Latitude'], row['Longitude']],
        radius=5,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.8,
        popup=popup,
        tooltip=row[['Retailer_ID','Beat_ID']]
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b7828cf4a43fc984d58adedd22a15363 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b7828cf4a43fc984d58adedd22a15363&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b7828cf4a43fc984d58adedd22a15363 = L.map(
#                 &quot;map_b7828cf4a43fc984d58adedd22a15363&quot;,
#                 {
#                     center: [12.897194583333334, 77.6020644],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1578225186d012d5207b9cec1d1e7893 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1578225186d012d5207b9cec1d1e7893.addTo(map_b7828cf4a43fc984d58adedd22a15363);
#
#
#             var circle_marker_7c7b6c5bac196c90b5a9aed1b48deee6 = L.circleMarker(
#                 [12.852501, 77.577503],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#91db57&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#91db57&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b7828cf4a43fc984d58adedd22a15363);
#
#
#         var popup_05d41056596e15c8fda814742657a20f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_41a96ad94f57a4a7f7458d15f25fc7c1 = $(`&lt;div id=&quot;html_41a96ad94f57a4a7f7458d15f25fc7c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Retailer: Aguirre PLC&lt;br&gt;Beat: B004&lt;/div&gt;`)[0];
#                 popup_05d41056596e15c8fda814742657a20f.setContent(html_41a96ad94f57a4a7f7458d15f25fc7c1);
#
#
#
#         circle_marker_7c7b6c5bac196c90b5a9aed1b48deee6.bindPopup(popup_05d41056596e15c8fda814742657a20f)
#         ;
#
#
#
#
#             circle_marker_7c7b6c5bac196c90b5a9aed1b48deee6.bindTooltip(
#                 `&lt;div&gt;
#                      Retailer_ID    R0001
# Beat_ID         B004
# Name: 0, dtype: object
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_fc0237fba1f5feff71623c15da2b8cfb = L.circleMarker(
#                 [12.863954, 77.56025],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#57d3db&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#57d3db&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b7828cf4a43fc984d58adedd22a15363);
#
#
#         var popup_c2d86aaa8e8841c48e3250c5aed45c81 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d47f3c1bebe0726fb534b9518379c1e1 = $(`&lt;div id=&quot;html_d47f3c1bebe0726fb534b9518379c1e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Retailer: Morales, Serrano and Hamilton&lt;br&gt;Beat: B007&lt;/div&gt;`)[0];
#                 popup_c2d86aaa8e8841c48e3250c5aed45c81.setContent(html_d47f3c1bebe0726fb534b9518379c1e1);
#
#
#
#         circle_marker_fc0237fba1f5feff71623c15da2b8cfb.bindPopup(popup_c2d86aaa8e8841c48e3250c5aed45c81)
#         ;
#
#
#
#
#             circle_marker_fc0237fba1f5feff71623c15da2b8cfb.bindTooltip(
#                 `&lt;div&gt;
#                      Retailer_ID    R0002
# Beat_ID         B007
# Name: 1, dtype: object
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_6052410df9d4bf827aa151ebbf8fbc2e = L.circleMarker(
#                 [12.909049, 77.553178],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#a157db&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#a157db&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b7828cf4a43fc984d58adedd22a15363);

# %% [markdown]
# #### beat optimization

# %%
# Parameters
NUM_BEATS = 12
MIN_BEAT_SIZE = 16
MAX_BEAT_SIZE = 24

# %%
retailer_ids = retailers_df["Retailer_ID"].tolist()
coords = retailers_df[["Latitude", "Longitude"]].to_numpy()
num_retailers = len(retailer_ids)

# %%
#Use KMeans to get initial cluster centers
kmeans = KMeans(n_clusters=NUM_BEATS, random_state=42).fit(coords)
initial_centers = kmeans.cluster_centers_

# %%
#Calculate distance matrix (Haversine in kilometers)
dist_matrix = np.zeros((num_retailers, NUM_BEATS))

for i in range(num_retailers):
    for j in range(NUM_BEATS):
        latlon_i = tuple(coords[i])  # (lat, lon)
        latlon_center = tuple(initial_centers[j]) 
        dist_matrix[i][j] = haversine(latlon_i, latlon_center, unit=Unit.KILOMETERS)

# %%
#Set up pulp optimization
model = pulp.LpProblem("ConstrainedClustering", pulp.LpMinimize)

# Binary decision variables: x[i][j] = 1 if retailer i assigned to cluster j
x = [
    [pulp.LpVariable(f"x_{i}_{j}", cat="Binary") for j in range(NUM_BEATS)]
    for i in range(num_retailers)
]

# %%
# Objective: Minimize total Haversine distance
model += pulp.lpSum(dist_matrix[i][j] * x[i][j] for i in range(num_retailers) for j in range(NUM_BEATS))

# %%
# Constraint 1: Each retailer must be assigned to exactly one beat
for i in range(num_retailers):
    model += pulp.lpSum(x[i][j] for j in range(NUM_BEATS)) == 1

# %%
# Constraint 2: Cluster sizes must be within bounds
for j in range(NUM_BEATS):
    model += pulp.lpSum(x[i][j] for i in range(num_retailers)) >= MIN_BEAT_SIZE
    model += pulp.lpSum(x[i][j] for i in range(num_retailers)) <= MAX_BEAT_SIZE

# %%
#solve the optimization problem
model.solve(pulp.PULP_CBC_CMD(msg=1))
# Out:
# 1

# %%
#Extract assignments
assignments = []
for i in range(num_retailers):
    for j in range(NUM_BEATS):
        if pulp.value(x[i][j]) == 1:
            assignments.append((retailer_ids[i], f"B{j+1:03d}"))
            break

# %%
optimized_beatmap_df = pd.DataFrame(assignments, columns=["Retailer_ID", "Beat_ID"])

# %%
optimized_beatmap_df['Retailer_ID'].nunique(),optimized_beatmap_df['Beat_ID'].nunique()
# Out:
# (240, 12)

# %%
optimized_beatmap_df.head(),retailer_map_df.head()
# Out:
# (  Retailer_ID Beat_ID
#  0       R0001    B012
#  1       R0002    B004
#  2       R0003    B008
#  3       R0004    B007
#  4       R0005    B009,
#    Retailer_ID Beat_ID
#  0       R0001    B004
#  1       R0002    B007
#  2       R0003    B010
#  3       R0004    B006
#  4       R0005    B010)

# %%
optimized_beatmap_df.to_sql("retailer_beat_map_optimized", conn, if_exists="replace", index=False)
# Out:
# 240

# %%
retailers_merged_optimized = pd.merge(retailers_df, optimized_beatmap_df, on="Retailer_ID")

# Generate color map for beats (12 unique colors)
beat_ids = sorted(retailers_merged_optimized["Beat_ID"].unique())
#colors = list(TABLEAU_COLORS.values())
colors = sns.color_palette("hls", NUM_BEATS).as_hex()
beat_color_map = {beat_id: colors[i % len(colors)] for i, beat_id in enumerate(beat_ids)}

# %%
len(colors)
# Out:
# 12

# %%
m = folium.Map(location=map_center, zoom_start=12)

# Add retailers with color by beat
for _, row in retailers_merged_optimized.iterrows():
    beat = row["Beat_ID"]
    color = beat_color_map[beat]
    popup = f"Retailer: {row['Name']}<br>Beat: {beat}"
    
    folium.CircleMarker(
        location=[row['Latitude'], row['Longitude']],
        radius=5,
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.8,
        popup=popup,
        tooltip=row[['Retailer_ID','Beat_ID']]
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f4d43d5b2c44f616dea41e8f851a2600 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f4d43d5b2c44f616dea41e8f851a2600&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f4d43d5b2c44f616dea41e8f851a2600 = L.map(
#                 &quot;map_f4d43d5b2c44f616dea41e8f851a2600&quot;,
#                 {
#                     center: [12.897194583333334, 77.6020644],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c5deac7171cf5259e4f00afddb706a35 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c5deac7171cf5259e4f00afddb706a35.addTo(map_f4d43d5b2c44f616dea41e8f851a2600);
#
#
#             var circle_marker_718febf700c13145e015077ba6f7f877 = L.circleMarker(
#                 [12.852501, 77.577503],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#db5791&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#db5791&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f4d43d5b2c44f616dea41e8f851a2600);
#
#
#         var popup_0e2397766da43314e359fd33be271aa3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_278fc5ef63349dcafeff44123c7649c2 = $(`&lt;div id=&quot;html_278fc5ef63349dcafeff44123c7649c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Retailer: Aguirre PLC&lt;br&gt;Beat: B012&lt;/div&gt;`)[0];
#                 popup_0e2397766da43314e359fd33be271aa3.setContent(html_278fc5ef63349dcafeff44123c7649c2);
#
#
#
#         circle_marker_718febf700c13145e015077ba6f7f877.bindPopup(popup_0e2397766da43314e359fd33be271aa3)
#         ;
#
#
#
#
#             circle_marker_718febf700c13145e015077ba6f7f877.bindTooltip(
#                 `&lt;div&gt;
#                      Retailer_ID    R0001
# Beat_ID         B012
# Name: 0, dtype: object
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_e447217363347421098480b0ad54645e = L.circleMarker(
#                 [12.863954, 77.56025],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#91db57&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#91db57&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f4d43d5b2c44f616dea41e8f851a2600);
#
#
#         var popup_232148f8430448bbf8614eb69ae17fdf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62424384b536c1f6e004fd4d9eaf9b25 = $(`&lt;div id=&quot;html_62424384b536c1f6e004fd4d9eaf9b25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Retailer: Morales, Serrano and Hamilton&lt;br&gt;Beat: B004&lt;/div&gt;`)[0];
#                 popup_232148f8430448bbf8614eb69ae17fdf.setContent(html_62424384b536c1f6e004fd4d9eaf9b25);
#
#
#
#         circle_marker_e447217363347421098480b0ad54645e.bindPopup(popup_232148f8430448bbf8614eb69ae17fdf)
#         ;
#
#
#
#
#             circle_marker_e447217363347421098480b0ad54645e.bindTooltip(
#                 `&lt;div&gt;
#                      Retailer_ID    R0002
# Beat_ID         B004
# Name: 1, dtype: object
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_96c74e69629720a8764644cfcf6353ec = L.circleMarker(
#                 [12.909049, 77.553178],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#5791db&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#5791db&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f4d43d5b2c44f616dea41e8f851a2600);

# %%
optimized_beatmap_df['Beat_ID'].value_counts()
# Out:
# Beat_ID
# B012    24
# B004    24
# B007    23
# B005    23
# B002    23
# B001    22
# B009    19
# B003    17
# B006    17
# B008    16
# B011    16
# B010    16
# Name: count, dtype: int64

# %%
def compute_tsp_route(beat_id, beat_retailers):
    coords = beat_retailers[["Latitude", "Longitude"]].to_numpy()
    retailer_ids = beat_retailers["Retailer_ID"].tolist()
    n = len(retailer_ids)

    # Build full distance matrix (in km)
    dist_matrix = np.zeros((n, n))
    for i in range(n):
        for j in range(i + 1, n):
            d = geodesic(coords[i], coords[j]).km
            dist_matrix[i][j] = dist_matrix[j][i] = d

    # Find outermost retailer (farthest from centroid)
    centroid = coords.mean(axis=0)
    dists_to_center = [geodesic(tuple(c), tuple(centroid)).km for c in coords]
    start_idx = int(np.argmax(dists_to_center))

    # Build complete graph with distance weights
    G = nx.complete_graph(n)
    for i in range(n):
        for j in range(n):
            if i != j:
                G[i][j]["weight"] = dist_matrix[i][j]

    # Approximate TSP without 'start' (avoid TypeError)
    #tsp_path = nx.approximation.traveling_salesman_problem(G, cycle=False, weight="weight", method="greedy")

    tsp_path = greedy_tsp(G, weight="weight")

    # Return final path as list of tuples
    return [(beat_id, retailer_ids[i], seq + 1) for seq, i in enumerate(tsp_path)]
    return [(beat_id, retailer_ids[i], seq + 1) for seq, i in enumerate(tsp_path)]

# %%
# Run TSP for each beat
all_routes = []
for beat_id in retailers_merged_optimized["Beat_ID"].unique():
    beat_retailers = retailers_merged_optimized[retailers_merged_optimized["Beat_ID"] == beat_id].reset_index(drop=True)
    route = compute_tsp_route(beat_id, beat_retailers)
    all_routes.extend(route)

# %%
route_df = pd.DataFrame(all_routes, columns=["Beat_ID", "Retailer_ID", "Visit_Sequence"])
route_df.head()
# Out:
#   Beat_ID Retailer_ID  Visit_Sequence
# 0    B012       R0001               1
# 1    B012       R0141               2
# 2    B012       R0053               3
# 3    B012       R0218               4
# 4    B012       R0199               5

# %%
route_df['Beat_ID'].nunique()
# Out:
# 12

# %%
route_df = pd.DataFrame(all_routes, columns=["Beat_ID", "Retailer_ID", "Visit_Sequence"])
route_df.to_sql("beat_route_plan", conn, if_exists="replace", index=False)
conn.commit()
# conn.close()

# %%
conn.close()

# %%
route_merged = pd.merge(route_df, retailers_df, on="Retailer_ID")
route_merged = route_merged.sort_values(by=["Beat_ID", "Visit_Sequence"])

# Create map centered on Bengaluru
center_lat, center_lon = retailers_df["Latitude"].mean(), retailers_df["Longitude"].mean()

# %%
beat_ids = sorted(route_merged["Beat_ID"].unique())
beat_color_map = {beat_id: colors[i % len(colors)] for i, beat_id in enumerate(beat_ids)}

# %%
print(route_merged[["Beat_ID", "Retailer_ID", "Visit_Sequence"]].sort_values(["Beat_ID", "Visit_Sequence"]).head(20))
print(route_merged["Visit_Sequence"].dtype)
# Out:
#     Beat_ID Retailer_ID  Visit_Sequence
# 128    B001       R0010               1
# 129    B001       R0171               2
# 130    B001       R0212               3
# 131    B001       R0210               4
# 132    B001       R0161               5
# 133    B001       R0043               6
# 134    B001       R0238               7
# 135    B001       R0104               8
# 136    B001       R0036               9
# 137    B001       R0069              10
# 138    B001       R0229              11
# 139    B001       R0101              12
# 140    B001       R0231              13
# 141    B001       R0139              14
# 142    B001       R0040              15
# 143    B001       R0143              16
# 144    B001       R0065              17
# 145    B001       R0046              18
# 146    B001       R0207              19
# 147    B001       R0090              20
# int64

# %%
m = folium.Map(location=map_center, zoom_start=12)

# Plot ant path for each beat
for beat_id in beat_ids:
    beat_route = route_merged[route_merged["Beat_ID"] == beat_id]
    locations = beat_route[["Latitude", "Longitude"]].values.tolist()

    AntPath(
        locations,
        color=beat_color_map[beat_id],
        weight=4,
        opacity=0.8,
        dash_array=[10, 20]
    ).add_to(m)

    
    for i, row in beat_route.iterrows():
        folium.CircleMarker(
            location=(row["Latitude"], row["Longitude"]),
            radius=3,
            fill=True,
            fill_opacity=0.9,
            popup=f"{row['Retailer_ID']} - {row['Visit_Sequence']}",
            color=beat_color_map[beat_id]
        ).add_to(m)

        folium.map.Marker(
        [row["Latitude"], row["Longitude"]],
        icon=folium.DivIcon(
            html=f"""<div style="font-size: 10pt; color: black"><b>{row['Visit_Sequence']-1}</b></div>"""
        )
        ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bbdc9f62850c3e740ffe38f027b99b0a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-ant-path@1.1.2/dist/leaflet-ant-path.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bbdc9f62850c3e740ffe38f027b99b0a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bbdc9f62850c3e740ffe38f027b99b0a = L.map(
#                 &quot;map_bbdc9f62850c3e740ffe38f027b99b0a&quot;,
#                 {
#                     center: [12.897194583333334, 77.6020644],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_63b51220ad2fe5b80d88eee7083de7e7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_63b51220ad2fe5b80d88eee7083de7e7.addTo(map_bbdc9f62850c3e740ffe38f027b99b0a);
#
#
#             ant_path_521cab1d09c7935b018e52f5918c1b5a = L.polyline.antPath(
#               [[12.934749, 77.610373], [12.933923, 77.612134], [12.937272, 77.607406], [12.947429, 77.605336], [12.948072, 77.603412], [12.947798, 77.603271], [12.949957, 77.617228], [12.947384, 77.624948], [12.947189, 77.626196], [12.942652, 77.628513], [12.942391, 77.628783], [12.939898, 77.629612], [12.940841, 77.632663], [12.939266, 77.636044], [12.94291, 77.637872], [12.945004, 77.639143], [12.9469, 77.642637], [12.946436, 77.642891], [12.948051, 77.633263], [12.938971, 77.624242], [12.935673, 77.626559], [12.934958, 77.632233], [12.934749, 77.610373]],
#               {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#db5f57&quot;,
#   &quot;weight&quot;: 4,
#   &quot;opacity&quot;: 0.8,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: [
# 10,
# 20,
# ],
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: false,
#   &quot;fillColor&quot;: &quot;#db5f57&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;smoothFactor&quot;: 1.0,
#   &quot;noClip&quot;: false,
#   &quot;paused&quot;: false,
#   &quot;reverse&quot;: false,
#   &quot;hardwareAcceleration&quot;: false,
#   &quot;delay&quot;: 400,
#   &quot;pulseColor&quot;: &quot;#FFFFFF&quot;,
# }
#         ).addTo(map_bbdc9f62850c3e740ffe38f027b99b0a);
#
#
#             var circle_marker_d63533636fe6648036ec6805b6c9786f = L.circleMarker(
#                 [12.934749, 77.610373],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#db5f57&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#db5f57&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bbdc9f62850c3e740ffe38f027b99b0a);
#
#
#         var popup_63f398e932f5b0381644826ac1d3b988 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_159182bd72738574b2ecf7568275cc37 = $(`&lt;div id=&quot;html_159182bd72738574b2ecf7568275cc37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;R0010 - 1&lt;/div&gt;`)[0];
#                 popup_63f398e932f5b0381644826ac1d3b988.setContent(html_159182bd72738574b2ecf7568275cc37);
#
#
#
#         circle_marker_d63533636fe6648036ec6805b6c9786f.bindPopup(popup_63f398e932f5b0381644826ac1d3b988)
#         ;
#
#
#
#
#             var marker_8605bad6b47388507f279f17dbb3655d = L.marker(
#                 [12.934749, 77.610373],
#                 {
# }
#             ).addTo(map_bbdc9f62850c3e740ffe38f027b99b0a);
#
#
#             var div_icon_d363b00ab9f9935f9d7f5fcc46e23337 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 10pt; color: black\&quot;\u003e\u003cb\u003e0\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_8605bad6b47388507f279f17dbb3655d.setIcon(div_icon_d363b00ab9f9935f9d7f5fcc46e23337);
#
#
#             var circle_marker_eb65a9176279f688dd8236c75c05e978 = L.circleMarker(
#                 [12.933923, 77.612134],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#db5f57&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#db5f57&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap
